# %% [markdown]
# # import dependecies

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # load the cleaned data

# %%
km_data = pd.read_csv("../data/kmeans_data.csv")
kp_data = pd.read_csv("../data/k_pro_data.csv")

# %%
km_data.head()
# Out:
#    minutes_watched     clv  clv_wins  region_USA/Canada/As  region_West_EU  \
# 0           3197.0  205.42    205.42                     0               0
# 1             63.0  149.99    149.99                     1               0
# 2            605.0  119.00    119.00                     0               0
# 3             20.0  240.00    240.00                     0               0
# 4            245.0  184.36    184.36                     0               1
#
#    channel_Friend  channel_Google  channel_Instagram  channel_LinkedIn  \
# 0               0               0                  0                 1
# 1               0               1                  0                 0
# 2               0               0                  0                 0
# 3               0               0                  0                 1
# 4               0               0                  0                 1
#
#    channel_Other  channel_Twitter  channel_YouTube
# 0              0                0                0
# 1              0                0                0
# 2              0                0                0
# 3              0                0                0
# 4              0                0                0

# %%
kp_data.head()
# Out:
#    Unnamed: 0  minutes_watched     clv  clv_wins             region   channel
# 0           0           3197.0  205.42    205.42  Rest_of_the_world  LinkedIn
# 1           1             63.0  149.99    149.99      USA/Canada/As    Google
# 2           2            605.0  119.00    119.00  Rest_of_the_world  Facebook
# 3           3             20.0  240.00    240.00  Rest_of_the_world  LinkedIn
# 4           4            245.0  184.36    184.36            West_EU  LinkedIn

# %% [markdown]
# # Dropping repeated columns

# %%
kmd = km_data.drop(columns={"clv"})

# %%
kpd = kp_data.drop(columns={"clv"})

# %% [markdown]
# ---

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler , StandardScaler

# %%
scale = StandardScaler()

# %%
km_data.loc[:,["minutes_watched" , "clv_wins"]] = scale.fit_transform(km_data.loc[:,["minutes_watched" , "clv_wins"]])

# %%
km_data
# Out:
#       minutes_watched     clv  clv_wins  region_USA/Canada/As  region_West_EU  \
# 0            0.173536  205.42  1.414667                     0               0
# 1           -0.255845  149.99  0.535605                     1               0
# 2           -0.181587  119.00  0.044135                     0               0
# 3           -0.261736  240.00  1.963070                     0               0
# 4           -0.230910  184.36  1.080677                     0               1
# ...               ...     ...       ...                   ...             ...
# 3829        -0.262969   79.00 -0.590224                     1               0
# 3830        -0.260640   79.00 -0.590224                     1               0
# 3831        -0.256667   36.00 -1.272159                     0               0
# 3832        -0.258448   36.00 -1.272159                     0               0
# 3833        -0.212345   79.00 -0.590224                     1               0
#
#       channel_Friend  channel_Google  channel_Instagram  channel_LinkedIn  \
# 0                  0               0                  0                 1
# 1                  0               1                  0                 0
# 2                  0               0                  0                 0
# 3                  0               0                  0                 1
# 4                  0               0                  0                 1
# ...              ...             ...                ...               ...
# 3829               0               0                  0                 0
# 3830               0               0                  0                 0
# 3831               0               0                  0                 0
# 3832               0               1                  0                 0
# 3833               0               0                  0                 0
#
#       channel_Other  channel_Twitter  channel_YouTube
# 0                 0                0                0
# 1                 0                0                0
# 2                 0                0                0
# 3                 0                0                0
# 4                 0                0                0
# ...             ...              ...              ...
# 3829              0                0                1
# 3830              0                0                0
# 3831              0                0                0
# 3832              0                0                0
# 3833              0                0                1
#
# [3834 rows x 12 columns]

# %%
kmd = km_data.drop(columns={"clv"})

# %% [markdown]
# # Model

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score

# %%
import mlflow 
import mlflow.sklearn

# %%
mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment("Customer_Segmentation_Experiment_1")

# %%
results = []

for k in range(2, 24): # choose from 2 to 11 K
    with mlflow.start_run(run_name=f"KMeans_K_{k}"):
    
        kmeans = KMeans(n_clusters=k, random_state=42)
        labels = kmeans.fit_predict(kmd)

        sil_score = silhouette_score(kmd, labels)
        dbi = davies_bouldin_score(kmd, labels)
        inertia = kmeans.inertia_

        results.append({
            'K': k,
            'Silhouette': sil_score,
            'Davies_Bouldin': dbi,
            'Inertia': inertia
        })

        mlflow.log_param("K", k)
        mlflow.log_metric("Silhouette", sil_score)
        mlflow.log_metric("Davies_Bouldin", dbi)
        mlflow.log_metric("Inertia", inertia)
        
        input_example = kmd[:5] if hasattr(kmd, "__getitem__") else None
        mlflow.sklearn.log_model(
            sk_model=kmeans,
            name=f"kmeans_model_k_{k}",
            input_example=input_example)
        
# results of DataFrame
results_df = pd.DataFrame(results)
print(results_df)

#-----------------------
# 3. choosing best K
#-----------------------
best_k_sil = results_df.loc[results_df['Silhouette'].idxmax(), 'K']
best_k_dbi = results_df.loc[results_df['Davies_Bouldin'].idxmin(), 'K']

print(f"\n✅ best K depending on Silhouette = {best_k_sil}")
print(f"✅ best K depending on Silhouette Davies–Bouldin = {best_k_dbi}")

#-----------------------
# 4. plotting
#-----------------------
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.plot(results_df['K'], results_df['Silhouette'], 'o-')
plt.xlabel('K')
plt.ylabel('Silhouette Score')
plt.title('Silhouette vs K')

plt.subplot(1,2,2)
plt.plot(results_df['K'], results_df['Davies_Bouldin'], 'o-', color='orange')
plt.xlabel('K')
plt.ylabel('Davies–Bouldin Index')
plt.title('Davies–Bouldin vs K')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 4
#       1 results = []
#       3 for k in range(2, 24): # choose from 2 to 11 K
# ----> 4     with mlflow.start_run(run_name=f"KMeans_K_{k}"):
#       6         kmeans = KMeans(n_clusters=k, random_state=42)
#       7         labels = kmeans.fit_predict(kmd)
#
# File ~/.AI/lib/python3.12/site-packages/mlflow/tracking/fluent.py:475, in start_run(run_id, experiment_id, run_name, nested, parent_run_id, tags, description, log_system_metrics)
#     471         user_specified_tags[MLFLOW_RUN_NAME] = run_name
#     473     resolved_tags = context_registry.resolve_tags(user_specified_tags)
# --> 475     active_run_obj = client.create_run(
#     476         experiment_id=exp_id_for_run,
#     477         tags=resolved_tags,
#     478         run_name=run_name,
#     479     )
#     481 if log_system_metrics is None:
#     482     # If `log_system_metrics` is not specified, we will check environment variable.
#     483     log_system_metrics = MLFLOW_ENABLE_SYSTEM_METRICS_LOGGING.get()
#
# File ~/.AI/lib/python3.12/site-packages/mlflow/tracking/client.py:479, in MlflowClient.create_run(self, experiment_id, start_time, tags, run_name)
#     425 def create_run(
#     426     self,
#     427     experiment_id: str,
#    (...)    430     run_name: str | None = None,
#     431 ) -> Run:
#     432     """
#     433     Create a :py:class:`mlflow.entities.Run` object that can be associated with
#     434     metrics, parameters, artifacts, etc.
#    (...)    477         status: RUNNING
#     478     """
# --> 479     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
#
# File ~/.AI/lib/python3.12/site-packages/mlflow/telemetry/track.py:30, in record_usage_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      28 start_time = time.time()
#      29 try:
# ---> 30     result = func(*args, **kwargs)
#      31     return result  # noqa: RET504
#      32 except Exception:
#
# File ~/.AI/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/client.py:183, in TrackingServiceClient.create_run(self, experiment_id, start_time, tags, run_name)
#     178 # Extract user from tags
#     179 # This logic is temporary; the user_id attribute of runs is deprecated and will be removed
#     180 # in a later release.
#     181 user_id = tags.get(MLFLOW_USER, "unknown")
# --> 183 return self.store.create_run(
#     184     experiment_id=experiment_id,
#     185     user_id=user_id,
#     186     start_time=start_time or get_current_time_millis(),
#     187     tags=[RunTag(key, value) for (key, value) in tags.items()],
#     188     run_name=run_name,
#     189 )
#
# File ~/.AI/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:338, in RestStore.create_run(self, experiment_id, user_id, start_time, tags, run_name)
#     328 tag_protos = [tag.to_proto() for tag in tags]
#     329 req_body = message_to_json(
#     330     CreateRun(
#     331         experiment_id=str(experiment_id),
#    (...)    336     )
#     337 )
# --> 338 response_proto = self._call_endpoint(CreateRun, req_body)
#     339 return Run.from_proto(response_proto.run)
#
# File ~/.AI/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:201, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     199     endpoint, method = self._METHOD_TO_INFO[api]
#     200 response_proto = response_proto or api.Response()
# --> 201 return call_endpoint(
#     202     self.get_host_creds(),
#     203     endpoint,
#     204     method,
#     205     json_body,
#     206     response_proto,
#     207     retry_timeout_seconds=retry_timeout_seconds,
#     208 )
#
# File ~/.AI/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:569, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     567 else:
#     568     call_kwargs["json"] = json_body
# --> 569     response = http_request(**call_kwargs)
#     571 response = verify_rest_response(response, endpoint)
#     572 response_to_parse = response.text
#
# File ~/.AI/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:232, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, retry_timeout_seconds, **kwargs)
#     229     kwargs["auth"] = fetch_auth(host_creds.auth)
#     231 try:
# --> 232     return _get_http_response_with_retries(
#     233         method,
#     234         url,
#     235         max_retries,
#     236         backoff_factor,
#     237         backoff_jitter,
#     238         retry_codes,
#     239         raise_on_status,
#     240         headers=headers,
#     241         verify=host_creds.verify,
#     242         timeout=timeout,
#     243         respect_retry_after_header=respect_retry_after_header,
#     244         **kwargs,
#     245     )
#     246 except requests.exceptions.Timeout as to:
#     247     raise MlflowException(
#     248         f"API request to {url} failed with timeout exception {to}."
#     249         " To increase the timeout, set the environment variable "
#     250         f"{MLFLOW_HTTP_REQUEST_TIMEOUT!s} to a larger value."
#     251     ) from to
#
# File ~/.AI/lib/python3.12/site-packages/mlflow/utils/request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     234 env_value = os.getenv("MLFLOW_ALLOW_HTTP_REDIRECTS", "true").lower() in ["true", "1"]
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File ~/.AI/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.AI/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.AI/lib/python3.12/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/.AI/lib/python3.12/site-packages/urllib3/connectionpool.py:942, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     940     retries.sleep(response)
#     941     log.debug("Retry: %s", url)
# --> 942     return self.urlopen(
#     943         method,
#     944         url,
#     945         body,
#     946         headers,
#     947         retries=retries,
#     948         redirect=redirect,
#     949         assert_same_host=assert_same_host,
#     950         timeout=timeout,
#     951         pool_timeout=pool_timeout,
#     952         release_conn=release_conn,
#     953         chunked=chunked,
#     954         body_pos=body_pos,
#     955         preload_content=preload_content,
#     956         decode_content=decode_content,
#     957         **response_kw,
#     958     )
#     960 return response
#
# File ~/.AI/lib/python3.12/site-packages/urllib3/connectionpool.py:942, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     940     retries.sleep(response)
#     941     log.debug("Retry: %s", url)
# --> 942     return self.urlopen(
#     943         method,
#     944         url,
#     945         body,
#     946         headers,
#     947         retries=retries,
#     948         redirect=redirect,
#     949         assert_same_host=assert_same_host,
#     950         timeout=timeout,
#     951         pool_timeout=pool_timeout,
#     952         release_conn=release_conn,
#     953         chunked=chunked,
#     954         body_pos=body_pos,
#     955         preload_content=preload_content,
#     956         decode_content=decode_content,
#     957         **response_kw,
#     958     )
#     960 return response
#
# File ~/.AI/lib/python3.12/site-packages/urllib3/connectionpool.py:940, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     937     return response
#     939 response.drain_conn()
# --> 940 retries.sleep(response)
#     941 log.debug("Retry: %s", url)
#     942 return self.urlopen(
#     943     method,
#     944     url,
#    (...)    957     **response_kw,
#     958 )
#
# File ~/.AI/lib/python3.12/site-packages/urllib3/util/retry.py:363, in Retry.sleep(self, response)
#     360     if slept:
#     361         return
# --> 363 self._sleep_backoff()
#
# File ~/.AI/lib/python3.12/site-packages/urllib3/util/retry.py:347, in Retry._sleep_backoff(self)
#     345 if backoff <= 0:
#     346     return
# --> 347 time.sleep(backoff)
#
# KeyboardInterrupt:

# %%
plt.plot(results_df["K"], results_df["Inertia"], 'o-')
plt.xlabel("K")
plt.ylabel("Inertia")
plt.title("Elbow Method")
plt.show()

# %%
from sklearn.metrics import silhouette_samples
import matplotlib.cm as cm

best_k = 10
kmeans = KMeans(n_clusters=best_k, random_state=42)
labels = kmeans.fit_predict(kmd)
sample_values = silhouette_samples(kmd, labels)
y_lower = 10
for i in range(best_k):
    ith_cluster_silhouette_values = sample_values[labels == i]
    ith_cluster_silhouette_values.sort()
    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i
    color = cm.nipy_spectral(float(i) / best_k)
    plt.fill_betweenx(np.arange(y_lower, y_upper),
                      0, ith_cluster_silhouette_values,
                      facecolor=color, edgecolor=color, alpha=0.7)
    y_lower = y_upper + 10
plt.xlabel("Silhouette Coefficient Values")
plt.ylabel("Cluster Label")
plt.title(f"Silhouette Plot for K = {best_k}")
plt.show()

# %%
wcss = []
for i in results:
    wcss.append(i["Inertia"])

# %%
k_range = range(2,24)
plt.figure(figsize=(8,5))
plt.plot(k_range, wcss, 'bo-', markersize=8)
plt.xlabel('Number of Clusters K')
plt.ylabel('WCSS (Inertia)')
plt.title('Elbow Method For Optimal K')
plt.grid(True)
plt.show()

# %% [markdown]
# # conclusion
# - the best K is 10 according to the metrics
